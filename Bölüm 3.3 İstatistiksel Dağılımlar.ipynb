# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import stats
import seaborn as sns
sns.set()
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
dagılım_adı=[33, 22, 38, 22, 140, 126, 20, 14, 44, 17, 14, 11, 21, 23, 122, 124, 27, 121, 12, 20, 19, 30, 
              117, 21, 16, 107, 17, 31, 25, 12, 27, 113, 15, 12, 11, 115, 121]

# %%
plt.figure(figsize=(8,4), dpi = 100)
plt.hist(dagılım, bins = 50)
plt.show()

# %%
plt.figure(figsize=(10,4), dpi = 100)
nsample = 100
res = stats.probplot(dagılım, plot=plt)
plt.show()


# Normal dağılıma yakın bir grafik oluştu. Ancak normal dağılımdan sapmalar var.

# %%
df=pd.read_csv("C:/Users/user/Downloads/GOOGL.csv")
a=[]    
for x in range ((len(df)-1)):   
    b= (df["Open"][x] - df["Open"][x+1])/df["Open"][x]
    a.append(b)

# %%
plt.figure(figsize=(10,4), dpi = 200)
nsample = 100
res = stats.probplot(a, plot=plt)
plt.title("XX Şirketinin 2015-2017 Yılları Arası Gelir Çizgesi")
plt.xlabel("Teorik Değerler")
plt.ylabel("Günlük Değişim Değeri")
plt.show()

# Normal Dağılıma çok yakın grafik oluştu.
