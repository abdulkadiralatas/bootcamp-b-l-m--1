# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
weather_aus=pd.read_csv("C:\\Users\\user\\Downloads\\archive\\weatherAUS.csv")

# %%
weather_aus
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0     2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1     2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2     2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3     2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4     2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 1140  2012-02-14   Albury     14.7     31.4       0.0          NaN       NaN
# 1141  2012-02-15   Albury     15.0     31.9       0.0          NaN       NaN
# 1142  2012-02-16   Albury     16.9     28.3       0.4          NaN       NaN
# 1143  2012-02-17   Albury     17.6     31.3       0.0          NaN       NaN
# 1144  2012-02-18   Albury     15.9     31.2       0.0          NaN       NaN
#
# ...

# %%
f=plt.figure(figsize=(10, 5))

plt.bar(weather_aus.MaxTemp, weather_aus.Rainfall, width=0.5, color="red", label="Yağış")
plt.ylabel("Yüksek ısı")
plt.xlabel("Yağış")
plt.legend()
plt.title("Yüksek ısı-Yağış Oranı")
plt.show()
